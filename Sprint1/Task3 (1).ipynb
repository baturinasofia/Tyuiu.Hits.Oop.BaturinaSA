// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания
// Вариант № 4

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Проект реализует иерархию классов для представления продуктов в интернет-магазине. Базовый класс Product содержит общую информацию о товарах (название, цена, производитель), а производные классы Electronics, Clothing и Books добавляют специфические атрибуты и методы. Реализованы принципы наследования, полиморфизма и инкапсуляции. В рамках дополнительного задания добавлены конструкторы с использованием явных геттеров и сеттеров, а также реализовано взаимодействие объектов между собой через класс ShoppingCart (корзина покупок).
//
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;

public class Product
{
    // Приватные поля для инкапсуляции
    private string _name;
    private decimal _price;
    private string _manufacturer;

    // Свойства с явными геттерами и сеттерами (с валидацией)
    public string Name
    {
        get { return _name; }
        set
        {
            if (!string.IsNullOrWhiteSpace(value))
                _name = value;
            else
                throw new ArgumentException("Название продукта не может быть пустым!");
        }
    }

    public decimal Price
    {
        get { return _price; }
        set
        {
            if (value > 0)
                _price = value;
            else
                throw new ArgumentOutOfRangeException("Цена должна быть больше нуля!");
        }
    }

    public string Manufacturer
    {
        get { return _manufacturer; }
        set
        {
            if (!string.IsNullOrWhiteSpace(value))
                _manufacturer = value;
            else
                throw new ArgumentException("Производитель не может быть пустым!");
        }
    }

    // Конструктор с использованием сеттеров
    public Product(string name, decimal price, string manufacturer)
    {
        Name = name;      // Используем сеттер с валидацией
        Price = price;    // Используем сеттер с валидацией
        Manufacturer = manufacturer; // Используем сеттер с валидацией
    }

    public virtual string GetInfo()
    {
        return $"Название: {Name}, Производитель: {Manufacturer}, Цена: {Price:C}";
    }

    public virtual decimal Discount()
    {
        decimal discountPrice = Price * 0.9m;
        Console.WriteLine($"[Product] Применена скидка 10% к '{Name}'. Новая цена: {discountPrice:C}");
        return discountPrice;
    }

    public virtual void Display()
    {
        Console.WriteLine($"=== {Name} ===");
        Console.WriteLine($"Производитель: {Manufacturer}");
        Console.WriteLine($"Цена: {Price:C}");
    }
}

public class Electronics : Product
{
    private int _warrantyPeriod;

    // Свойство с явными геттером и сеттером
    public int WarrantyPeriod
    {
        get { return _warrantyPeriod; }
        set
        {
            if (value >= 0)
                _warrantyPeriod = value;
            else
                throw new ArgumentOutOfRangeException("Гарантийный срок не может быть отрицательным!");
        }
    }

    // Конструктор с использованием сеттеров
    public Electronics(string name, decimal price, string manufacturer, int warrantyPeriod)
        : base(name, price, manufacturer)
    {
        WarrantyPeriod = warrantyPeriod; // Используем сеттер
    }

    public override decimal Discount()
    {
        decimal discountRate = WarrantyPeriod >= 24 ? 0.95m : 0.85m;
        decimal discountPrice = Price * discountRate;
        
        Console.WriteLine($"[Electronics] Скидка для '{Name}' (гарантия {WarrantyPeriod} мес.): " +
                         $"{(100 - discountRate * 100)}%. Новая цена: {discountPrice:C}");
        return discountPrice;
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Гарантия: {WarrantyPeriod} мес.";
    }

    public void ExtendWarranty(int extraMonths)
    {
        WarrantyPeriod += extraMonths;
        Console.WriteLine($"[Electronics] Гарантия для '{Name}' продлена на {extraMonths} мес. " +
                         $"Итого: {WarrantyPeriod} мес.");
    }
}

public class Clothing : Product
{
    private string _size;

    // Свойство с явными геттером и сеттером
    public string Size
    {
        get { return _size; }
        set
        {
            if (!string.IsNullOrWhiteSpace(value))
                _size = value;
            else
                throw new ArgumentException("Размер не может быть пустым!");
        }
    }

    // Конструктор с использованием сеттеров
    public Clothing(string name, decimal price, string manufacturer, string size)
        : base(name, price, manufacturer)
    {
        Size = size; // Используем сеттер
    }

    public override void Display()
    {
        Console.WriteLine($"=== {Name} ===");
        Console.WriteLine($"Производитель: {Manufacturer}");
        Console.WriteLine($"Размер: {Size}");
        Console.WriteLine($"Цена: {Price:C}");
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Размер: {Size}";
    }

    public bool IsSizeAvailable(string customerSize)
    {
        bool isAvailable = customerSize == Size;
        Console.WriteLine($"[Clothing] Размер '{customerSize}' для '{Name}': " +
                         $"{(isAvailable ? "в наличии" : "нет в наличии")}");
        return isAvailable;
    }
}

public class Books : Product
{
    private string _author;
    private int _pages;

    // Свойства с явными геттерами и сеттерами
    public string Author
    {
        get { return _author; }
        set
        {
            if (!string.IsNullOrWhiteSpace(value))
                _author = value;
            else
                throw new ArgumentException("Автор не может быть пустым!");
        }
    }

    public int Pages
    {
        get { return _pages; }
        set
        {
            if (value > 0)
                _pages = value;
            else
                throw new ArgumentOutOfRangeException("Количество страниц должно быть больше нуля!");
        }
    }

    // Конструктор с использованием сеттеров
    public Books(string name, decimal price, string manufacturer, string author, int pages)
        : base(name, price, manufacturer)
    {
        Author = author;  // Используем сеттер
        Pages = pages;    // Используем сеттер
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Автор: {Author}, Страниц: {Pages}";
    }

    public override decimal Discount()
    {
        decimal discountRate = Pages > 500 ? 0.8m : 0.9m;
        decimal discountPrice = Price * discountRate;
        
        Console.WriteLine($"[Books] Скидка для книги '{Name}' ({Pages} стр.): " +
                         $"{(100 - discountRate * 100)}%. Новая цена: {discountPrice:C}");
        return discountPrice;
    }

    public void ShowAuthorInfo()
    {
        Console.WriteLine($"[Books] Книга '{Name}' написана автором: {Author}");
    }
}

// ==================== ВЗАИМОДЕЙСТВИЕ ОБЪЕКТОВ ====================

public class ShoppingCart
{
    private List<Product> _items;
    private string _customerName;

    public string CustomerName
    {
        get { return _customerName; }
        set { _customerName = value; }
    }

    public ShoppingCart(string customerName)
    {
        _items = new List<Product>();
        CustomerName = customerName;
    }

    // ВЗАИМОДЕЙСТВИЕ: добавление продукта в корзину
    public void AddProduct(Product product)
    {
        _items.Add(product);
        Console.WriteLine($"[Корзина] {product.Name} добавлен в корзину {CustomerName}");
    }

    // ВЗАИМОДЕЙСТВИЕ: применение скидок ко всем товарам
    public void ApplyDiscountsToAll()
    {
        Console.WriteLine($"\n[Корзина] Применение скидок для {CustomerName}:");
        foreach (var item in _items)
        {
            item.Discount();
        }
    }

    // ВЗАИМОДЕЙСТВИЕ: подсчет общей стоимости
    public decimal CalculateTotal()
    {
        decimal total = 0;
        foreach (var item in _items)
        {
            total += item.Price;
        }
        return total;
    }

    // ВЗАИМОДЕЙСТВИЕ: отображение содержимого корзины
    public void DisplayCart()
    {
        Console.WriteLine($"\n=== Корзина покупателя: {CustomerName} ===");
        foreach (var item in _items)
        {
            Console.WriteLine($"• {item.GetInfo()}");
        }
        Console.WriteLine($"\nОбщая стоимость: {CalculateTotal():C}");
    }

    // ВЗАИМОДЕЙСТВИЕ: поиск товаров по производителю
    public void FindByManufacturer(string manufacturer)
    {
        Console.WriteLine($"\n[Корзина] Товары от производителя '{manufacturer}':");
        bool found = false;
        foreach (var item in _items)
        {
            if (item.Manufacturer.Equals(manufacturer, StringComparison.OrdinalIgnoreCase))
            {
                Console.WriteLine($"  ✓ {item.Name}");
                found = true;
            }
        }
        if (!found)
            Console.WriteLine("  Товары не найдены");
    }
}

// ==================== ОСНОВНАЯ ПРОГРАММА ====================

Console.WriteLine("=== СОЗДАНИЕ ПРОДУКТОВ ===\n");

var products = new List<Product>
{
    new Electronics("Смартфон Galaxy S23", 79999m, "Samsung", 24),
    new Electronics("Ноутбук ProBook", 125000m, "HP", 12),
    new Clothing("Футболка спортивная", 2499m, "Adidas", "L"),
    new Clothing("Джинсы классические", 4999m, "Levi's", "32"),
    new Books("Изучаем C#", 2999m, "Питер", "Герберт Шилдт", 1200),
    new Books("Алгоритмы", 3499m, "Вильямс", "Томас Кормен", 960)
};

Console.WriteLine("\n=== ИНФОРМАЦИЯ О ВСЕХ ПРОДУКТАХ ===\n");
foreach (var p in products)
{
    Console.WriteLine($"• {p.GetInfo()}");
}

Console.WriteLine("\n=== ВЗАИМОДЕЙСТВИЕ ОБЪЕКТОВ: КОРЗИНА ПОКУПАТЕЛЯ ===\n");

// Создание корзины и добавление товаров (взаимодействие объектов)
var cart1 = new ShoppingCart("Иван Петров");
cart1.AddProduct(products[0]); // Смартфон
cart1.AddProduct(products[2]); // Футболка
cart1.AddProduct(products[4]); // Книга

cart1.DisplayCart();
cart1.ApplyDiscountsToAll();
cart1.FindByManufacturer("Samsung");

// Вторая корзина
var cart2 = new ShoppingCart("Мария Сидорова");
cart2.AddProduct(products[1]); // Ноутбук
cart2.AddProduct(products[3]); // Джинсы
cart2.AddProduct(products[5]); // Алгоритмы

cart2.DisplayCart();
cart2.ApplyDiscountsToAll();

Console.WriteLine("\n=== ДОПОЛНИТЕЛЬНЫЕ МЕТОДЫ ===\n");

var electronics = (Electronics)products[0];
electronics.ExtendWarranty(12);

var clothing = (Clothing)products[2];
clothing.IsSizeAvailable("L");

var book = (Books)products[4];
book.ShowAuthorInfo();

Console.WriteLine("\n=== ИТОГОВАЯ ИНФОРМАЦИЯ ===\n");
foreach (var p in products)
{
    Console.WriteLine($"• {p.GetInfo()}");
}
// Out:
// === СОЗДАНИЕ ПРОДУКТОВ ===
//
//
// === ИНФОРМАЦИЯ О ВСЕХ ПРОДУКТАХ ===
//
// • Название: Смартфон Galaxy S23, Производитель: Samsung, Цена: ¤79,999.00, Гарантия: 24 мес.
// • Название: Ноутбук ProBook, Производитель: HP, Цена: ¤125,000.00, Гарантия: 12 мес.
// • Название: Футболка спортивная, Производитель: Adidas, Цена: ¤2,499.00, Размер: L
// • Название: Джинсы классические, Производитель: Levi's, Цена: ¤4,999.00, Размер: 32
// • Название: Изучаем C#, Производитель: Питер, Цена: ¤2,999.00, Автор: Герберт Шилдт, Страниц: 1200
// • Название: Алгоритмы, Производитель: Вильямс, Цена: ¤3,499.00, Автор: Томас Кормен, Страниц: 960
//
// === ВЗАИМОДЕЙСТВИЕ ОБЪЕКТОВ: КОРЗИНА ПОКУПАТЕЛЯ ===
//
// [Корзина] Смартфон Galaxy S23 добавлен в корзину Иван Петров
// [Корзина] Футболка спортивная добавлен в корзину Иван Петров
// [Корзина] Изучаем C# добавлен в корзину Иван Петров
//
// === Корзина покупателя: Иван Петров ===
// ...
